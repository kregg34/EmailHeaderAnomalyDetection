# %%
import pandas as pd
import shutil
from os import listdir, mkdir, path
from pathlib import Path
import sys
from email.parser import HeaderParser
import collections
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import time
from collections import Counter

# %%
parser = HeaderParser()
columns = ['received1',
'received2',
'received3',
'received4',
'received5',
'received6',
'received7',
'received8',
'hops',
'subject',
'date',
'message-id',
'from',
'return-path',
'to',
'content-type',
'mime-version',
'x-mailer',
'content-transfer-encoding',
'x-mimeole',
'x-priority',
'list-id',
'lines',
'x-virus-scanned',
'status',
'content-length',
'precedence',
'delivered-to',
'list-unsubscribe',
'list-subscribe',
'list-post',
'list-help',
'x-msmail-priority',
'x-spam-status',
'sender',
'errors-to',
'x-beenthere',
'list-archive',
'reply-to',
'x-mailman-version',
'x-miltered',
'x-uuid',
'x-virus-status',
'x-spam-level',
'x-spam-checker-version',
'references',
'in-reply-to',
'user-agent',
'thread-index',
'cc',
'received-spf',
'x-original-to',
'content-disposition',
'mailing-list',
'x-spam-check-by',
'domainkey-signature',
'importance',
'x-mailing-list',
'label']

list_of_rows = []


def addEmailsToDict(email_list):
    global parser, list_of_rows
    
    # The label for phishing, set to '2'
    label = 2
    
    
    # Read the full email content
    for email in email_list:
        row_dict = {}
        
        # Parse the email content
        h = parser.parsestr(email)

        # Parse recieved field
        received_list = h.get_all('received')
        hops = 0
        if received_list is not None:
            hops = len(received_list)
            col_name_recieved = 'received'

            for inx, received_field in enumerate(received_list):
                col = col_name_recieved + str(inx+1)
                row_dict[col] = received_field


        # Make everything lowercase to avoid issues
        features_lower_case = [x.lower() for x in h.keys()]

        # Parse everything else
        new_row = dict(zip(features_lower_case, h.values()))
        new_row['hops'] = hops


        for key,value in new_row.items():
            if key in columns:
                row_dict['label'] = label
                row_dict[key] = value


        list_of_rows.append(row_dict)

def main():
    global list_of_rows

    file_path = 'Phishing Dataset/phishing-2017.txt'
    
    # Read the full email content
    emailStr = ''
    try:
        with open(file_path, encoding='latin_1') as emailFile:
            for line in emailFile:
                emailStr += line
    except UnicodeDecodeError:
        print('Unicode Error!')
    
    email_list = emailStr.split('\nFrom jose@monkey.org')
    #print(email_list[1])
    
    addEmailsToDict(email_list)
    
    # Create the dataframe
    df = pd.DataFrame(list_of_rows)
    
    final_columns = []
    for col in columns:
        if col in df.columns:
            final_columns.append(col)
            
    df = df[final_columns]
    
    # Output the dataframe to a .csv file
    df.to_csv('phishing_out_2017V2.csv', index=False)

if __name__ == '__main__':
    main()

# %% [markdown]
# **Show the most common header fields:**

# %%
parser = HeaderParser()
dict_header_features = {}
total_emails = 0


def addEmailsToDict(email_list):
    global parser, dict_header_features, total_emails
    
    # Read the full email content
    for email in email_list:
        
        total_emails += 1
        h = parser.parsestr(email)
        features_lower_case = [x.lower() for x in h.keys()]
        features_dict = Counter(features_lower_case)

        for k,v in features_dict.items():
            if k in dict_header_features:
                dict_header_features[k] += 1
            else:
                dict_header_features[k] = 1

                
def main():
    global dict_header_features, total_emails
        
    file_path_list = ['Phishing Dataset/phishing-2017.txt', 'Phishing Dataset/phishing-2018.txt',
                     'Phishing Dataset/phishing-2019.txt', 'Phishing Dataset/phishing-2020.txt']
    
    for file_path in file_path_list:
        # Read the full email content
        emailStr = ''
        try:
            with open(file_path, encoding='latin_1') as emailFile:
                for line in emailFile:
                    emailStr += line
        except UnicodeDecodeError:
            print('Unicode Error!')

        email_list = emailStr.split('\nFrom jose@monkey.org')
        #print(email_list[1])

        addEmailsToDict(email_list)
        
    dict_header_features = sorted(dict_header_features.items(), key=lambda x:x[1], reverse=True)

    for v in dict_header_features:
        print(v)
        
    unzipped = list(zip(*dict_header_features))
    lab = unzipped[0]
    val = unzipped[1]
    print("TOTAL EMAIL COUNT:", total_emails)
    val = [x/total_emails for x in val]
    figure(figsize=(15, 6))
    axes = plt.gca()
    axes.set_ylim([0,1])
    plt.xticks(rotation='vertical')
    plt.ylabel('Percent of total emails')
    plt.bar(lab[0:20], val[0:20], width=0.25)
    plt.grid()
    plt.savefig('most_common_header_features_phish.png', bbox_inches="tight")
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# ('date', 1012)
# ('from', 1012)
# ('subject', 1012)
# ('status', 1010)
# ('return-path', 1009)
# ('delivered-to', 1009)
# ('x-fda', 1009)
# ('x-spam-summary', 1009)
# ('x-he-tag', 1009)
# ('received', 1009)
# ('content-type', 1008)
# ('x-status', 1007)
# ('x-keywords', 1007)
# ('x-uid', 1007)
# ('x-filterd-recvd-size', 1000)
# ('mime-version', 1000)
# ('to', 968)
# ('message-id', 837)
# ('content-transfer-encoding', 320)
# ('dkim-signature', 259)
# ('reply-to', 143)
# ('x-authenticated-sender', 137)
# ('x-antiabuse', 133)
# ('x-get-message-sender-via', 132)
# ('x-originating-ip', 120)
# ('x-priority', 108)
# ('thread-index', 105)
# ('x-source', 105)
# ('x-source-args', 105)
# ('x-source-dir', 105)
# ('thread-topic', 101)
# ('content-language', 93)
# ('x-ms-has-attach', 93)
# ('x-ms-tnef-correlator', 93)
# ('accept-language', 92)
# ('x-mailer', 86)
# ('x-virus-scanned', 83)
# ('x-sg-eid', 71)
# ('x-php-originating-script', 64)
# ('authentication-results', 61)
# ('received-spf', 45)
# ('references', 42)
# ('x-msmail-priority', 40)
# ('in-reply-to', 39)
# ('x-spam-status', 34)
# ('x-originalarrivaltime', 33)
# ('importance', 33)
# ('x-php-script', 32)
# ('x-microsoft-antispam', 29)
# ('x-originatororg', 29)
# ('x-ms-exchange-crosstenant-originalarrivaltime', 29)
# ('x-ms-exchange-crosstenant-fromentityheader', 29)
# ('x-ms-exchange-transport-crosstenantheadersstamped', 29)
# ('x-forefront-antispam-report', 28)
# ('x-ms-office365-filtering-correlation-id', 28)
# ('x-microsoft-antispam-prvs', 28)
# ('x-microsoft-exchange-diagnostics', 26)
# ('x-ms-publictraffictype', 26)
# ('priority', 26)
# ('x-exchange-antispam-report-cfa-test', 25)
# ('x-forefront-prvs', 25)
# ('x-ms-exchange-crosstenant-id', 25)
# ('spamdiagnosticoutput', 24)
# ('x-mimeole', 23)
# ('x-ms-traffictypediagnostic', 23)
# ('x-exchange-antispam-report-test', 22)
# ('x-google-dkim-signature', 20)
# ('x-gm-message-state', 20)
# ('x-received', 20)
# ('domainkey-signature', 20)
# ('list-unsubscribe', 19)
# ('sender', 18)
# ('x-antivirus', 16)
# ('x-microsoft-antispam-message-info', 16)
# ('x-ms-exchange-crosstenant-network-message-id', 16)
# ('x-ironport-av', 14)
# ('x-antivirus-status', 14)
# ('x-clientproxiedby', 14)
# ('x-cm-score', 13)
# ('dkim-filter', 13)
# ('x-sender', 13)
# ('user-agent', 13)
# ('x-ms-exchange-transport-fromentityheader', 12)
# ('x-return-path', 11)
# ('x-spam-level', 11)
# ('x-outgoing-spam-status', 11)
# ('x-google-smtp-source', 11)
# ('x-rspamd-queue-id', 11)
# ('x-rspamd-server', 11)
# ('x-relaying-domain', 10)
# ('x-eopattributedmessage', 10)
# ('x-authority-analysis', 10)
# ('x-ms-exchange-senderadcheck', 10)
# ('x-report-abuse-to', 9)
# ('x-ms-exchange-crosstenant-originalattributedtenantconnectingip', 9)
# ('x-brightmail-tracker', 9)
# ('x-stat-signature', 9)
# ('x-spam-processed', 8)
# ('x-mdremoteip', 8)
# ('x-envelope-from', 8)
# ('x-mdaemon-deliver-to', 8)
# ('x-spam-flag', 8)
# ('x-spam-checker-version', 8)
# ('x-recommended-action', 8)
# ('x-filter-id', 8)
# ('x-ct-class', 8)
# ('x-ct-score', 8)
# ('x-ct-refid', 8)
# ('x-ct-spam', 8)
# ('x-tm-as-result', 8)
# ('bcc', 8)
# ('x-ironport-anti-spam-filtered', 7)
# ('x-ironport-anti-spam-result', 7)
# ('x-spam-score', 7)
# ('x-proofpoint-virus-version', 7)
# ('x-tm-as-product-ver', 7)
# ('x-ipas-result', 6)
# ('sensitivity', 6)
# ('x-virus-status', 6)
# ('x-scanned-by', 6)
# ('x-no-relay', 6)
# ('x-spamexperts-domain', 6)
# ('x-spamexperts-username', 6)
# ('x-spamexperts-outgoing-class', 6)
# ('x-spamexperts-outgoing-evidence', 6)
# ('x-auditid', 6)
# ('x-tmase-matchedrid', 6)
# ('x-entity-id', 6)
# ('acceptlanguage', 5)
# ('x-proofpoint-spam-reason', 5)
# ('x-id', 5)
# ('x-toi-msgid', 5)
# ('x-imss-scan-details', 5)
# ('x-mailgun-sending-ip', 5)
# ('x-mailgun-sid', 5)
# ('x-tmase-result', 5)
# ('x-tmase-version', 5)
# ('x-easynet-es-outgoing-spam-score', 5)
# ('x-outgoing-spam-report', 5)
# ('x-outgoing-spamscan-signature', 5)
# ('x-easynet-bounce-key', 5)
# ('content-class', 4)
# ('x_cmae_category', 4)
# ('x-cnfs-analysis', 4)
# ('x-authed-username', 4)
# ('x-mailer-lid', 4)
# ('x-mailer-recptid', 4)
# ('x-mailer-sid', 4)
# ('x-mailer-sent-by', 4)
# ('spamdiagnosticmetadata', 4)
# ('x-php-filename', 4)
# ('x-tm-as-user-approved-sender', 4)
# ('x-tm-as-user-blocked-sender', 4)
# ('x-env-sender', 4)
# ('x-msg-ref', 4)
# ('x-starscan-received', 4)
# ('x-starscan-version', 4)
# ('x-kse-serverinfo', 4)
# ('x-kse-antivirus-interceptor-info', 4)
# ('x-kse-antivirus-info', 4)
# ('precedence', 4)
# ('x-mailscanner-from', 4)
# ('x-sasi-rcode', 4)
# ('x-asg-debug-id', 4)
# ('x-barracuda-envelope-from', 4)
# ('x-asg-orig-subj', 4)
# ('x-barracuda-connect', 4)
# ('x-barracuda-start-time', 4)
# ('x-barracuda-url', 4)
# ('x-barracuda-scan-msg-size', 4)
# ('x-barracuda-brts-status', 4)
# ('x-barracuda-spam-score', 4)
# ('x-barracuda-spam-status', 4)
# ('x-barracuda-spam-report', 4)
# ('x-sg-id', 4)
# ('x-spam-scanned', 4)
# ('x-locaweb-id', 4)
# ('x-he-dkim-result', 4)
# ('x-imap', 3)
# ('x-cyberoam-smtpxy-version', 3)
# ('x-cyberoam-av-policy', 3)
# ('x-yahoo-newman-property', 3)
# ('x-yahoo-newman-id', 3)
# ('x-ymail-osg', 3)
# ('x-msw-jemd-refid', 3)
# ('disposition-notification-to', 3)
# ('x-viruschecked', 3)
# ('x-auth-id', 3)
# ('x-footer', 3)
# ('list-id', 3)
# ('x-csa-complaints', 3)
# ('x-authuser', 3)
# ('x-mdav-processed', 3)
# ('x-mailscanner-id', 3)
# ('x-symc-ess-client-auth', 3)
# ('feedback-id', 3)
# ('recipient-id', 3)
# ('x-debug', 3)
# ('x-email-rejection-mode', 3)
# ('x-api-host', 3)
# ('site-id', 3)
# ('x-bounceemailversion', 3)
# ('x-pmx-version', 3)
# ('x-crosspremisesheadersfilteredbysendconnector', 3)
# ('x-organizationheaderspreserved', 3)
# ('x-dkim', 3)
# ('x-tm-as-gconf', 3)
# ('x-tmase-snap-result', 3)
# ('x-barracuda-effective-source-ip', 3)
# ('x-barracuda-apparent-source-ip', 3)
# ('mail-reply-to', 3)
# ('x-locaweb-id2', 3)
# ('x-message-uid', 3)
# ('x-account-uid', 3)
# ('x-envid', 3)
# ('arc-seal', 3)
# ('arc-message-signature', 3)
# ('arc-authentication-results', 3)
# ('x-ms-oob-tlc-oobclassifiers', 3)
# ('x-ms-exchange-antispam-messagedata', 3)
# ('x-ms-exchange-transport-forked', 3)
# ('x-ms-exchange-crosstenant-authas', 3)
# ('x-ms-exchange-crosstenant-authsource', 3)
# ('x-ms-exchange-crosstenant-mailboxtype', 3)
# ('x-ms-exchange-crosstenant-userprincipalname', 3)
# ('content-length', 2)
# ('ironport-phdr', 2)
# ('x-vpm-host', 2)
# ('x-vpm-group-id', 2)
# ('x-vpm-msg-id', 2)
# ('x-vpm-enc-regime', 2)
# ('x-vpm-is-hybrid', 2)
# ('x-exclaimer-md-config', 2)
# ('x-mb-message-source', 2)
# ('x-mb-message-type', 2)
# ('x-aol-sid', 2)
# ('x-netcomp-mailscanner-information', 2)
# ('x-netcomp-mailscanner-id', 2)
# ('x-netcomp-mailscanner', 2)
# ('x-netcomp-mailscanner-spamscore', 2)
# ('x-netcomp-mailscanner-from', 2)
# ('content-disposition', 2)
# ('x-canit-geo', 2)
# ('x-canitpro-stream', 2)
# ('x-canit-stats-id', 2)
# ('return-receipt-to', 2)
# ('x-sa-exim-connect-ip', 2)
# ('x-sa-exim-mail-from', 2)
# ('x-sa-exim-version', 2)
# ('x-sa-exim-scanned', 2)
# ('x-ms-office365-filtering-ht', 2)
# ('x-mail', 2)
# ('x-spam', 2)
# ('x-kse-attachment-filter-scan-result', 2)
# ('x-mdhelo', 2)
# ('x-mdarrival-date', 2)
# ('x-cav-result', 2)
# ('x-wb-res', 2)
# ('x-msw-jemd-newsletter', 2)
# ('x-claimtheweb-mailscanner-information', 2)
# ('x-claimtheweb-mailscanner-id', 2)
# ('x-claimtheweb-mailscanner', 2)
# ('x-claimtheweb-mailscanner-spamcheck', 2)
# ('x-claimtheweb-mailscanner-from', 2)
# ('x-mimectl', 2)
# ('x-proofpoint-virus-status', 2)
# ('x-me-helo', 2)
# ('x-me-date', 2)
# ('x-me-ip', 2)
# ('x-ctch-refid', 2)
# ('x-ctch-vod', 2)
# ('x-ctch-spam', 2)
# ('x-virus-checked', 2)
# ('x-ms-exchange-messagesentrepresentingtype', 2)
# ('x-mc-unique', 2)
# ('x-mimecast-spam-score', 2)
# ('x-intloopheader', 2)
# ('x-smtp33-mailscanner-information', 2)
# ('x-smtp33-mailscanner', 2)
# ('x-mlf-version', 2)
# ('x-mlf-license', 2)
# ('x-mlf-uniqueid', 2)
# ('x-bounce-tracking-info', 2)
# ('x-authority-reason', 2)
# ('x-bwhitelist', 2)
# ('x-source-ip', 2)
# ('x-source-l', 2)
# ('x-exim-id', 2)
# ('x-source-sender', 2)
# ('x-source-auth', 2)
# ('x-email-count', 2)
# ('x-source-cap', 2)
# ('x-local-domain', 2)
# ('ironport-sdr', 2)
# ('x-ses-outgoing', 2)
# ('x-barracuda-rbl-trusted-forwarder', 2)
# ('x-barracuda-rbl-ip', 2)
# ('x-barracuda-encrypted', 2)
# ('x-kse-attachment-filter-triggered-rules', 2)
# ('x-kse-attachment-filter-triggered-filters', 2)
# ('x-kse-bulkmessagesfiltering-scan-result', 2)
# ('x-classification-id', 2)
# ('x-spamd-result', 2)
# ('x-mimetrack', 1)
# ('x-pmwin-version', 1)
# ('x-msw-jemd-spam', 1)
# ('x-rc-from', 1)
# ('x-dlp-outbound', 1)
# ('x-mag-outbound', 1)
# ('x-modus-blacklist', 1)
# ('x-modus-trusted', 1)
# ('x-modus-spam-version', 1)
# ('x-modus-audit', 1)
# ('x-spam-ctch-refid', 1)
# ('x-aol-global-disposition', 1)
# ('x-aol-reroute', 1)
# ('x-suspect-keyword', 1)
# ('x-hermes-message-id', 1)
# ('x-hm-ut', 1)
# ('x-bayes-prob', 1)
# ('x-microsoft-exchange-diagnostics-untrusted', 1)
# ('x-microsoft-antispam-untrusted', 1)
# ('x-forefront-antispam-report-untrusted', 1)
# ('x-ms-exchange-transport-crosstenantheadersstripped', 1)
# ('x-dkimresult-test', 1)
# ('x-nai-spam-flag', 1)
# ('x-nai-spam-level', 1)
# ('x-nai-spam-threshold', 1)
# ('x-nai-spam-score', 1)
# ('x-nai-spam-version', 1)
# ('x-disclaimer', 1)
# ('x-imss-dkim-white-list', 1)
# ('x-ait-server-origin', 1)
# ('x-ait-path-origin', 1)
# ('x-ait-rev', 1)
# ('x-marr-info', 1)
# ('x-kerio-anti-spam', 1)
# ('x-antivirus-mydomain-mail-from', 1)
# ('x-antivirus-mydomain', 1)
# ('x-antivirus-mydomain-message-id', 1)
# ('x-job', 1)
# ('x-proofpoint-spam-details', 1)
# ('x-hospedandoantispam-domain', 1)
# ('x-hospedandoantispam-username', 1)
# ('x-hospedandoantispam-outgoing-class', 1)
# ('x-hospedandoantispam-outgoing-evidence', 1)
# ('x-dnsrbl', 1)
# ('organization', 1)
# ('x-xm-spf', 1)
# ('x-spam-report', 1)
# ('x-spam-dcc', 1)
# ('x-spam-combo', 1)
# ('x-spam-relay-country', 1)
# ('x-spam-timing', 1)
# ('x-disclaimer-applied', 1)
# ('x-7fa49cb5', 1)
# ('x-mailru-sender', 1)
# ('x-mras', 1)
# ('x-kse-antispam-interceptor-info', 1)
# ('x-kse-dlp-scaninfo', 1)
# ('x-proofpoint-virus-details', 1)
# ('content-description', 1)
# ('x-mailscanner', 1)
# ('x-mailscanner-spamscore', 1)
# ('x-sussex', 1)
# ('x-sussex-transport', 1)
# ('x-rule-processed-ssl01', 1)
# ('x-msfbl', 1)
# ('x-wb-msg-id', 1)
# ('x-assp-version', 1)
# ('x-assp-id', 1)
# ('x-assp-session', 1)
# ('x-assp-envelope-from', 1)
# ('x-assp-intended-for', 1)
# ('x-assp-original-subject', 1)
# ('x-assp-client-tls', 1)
# ('x-report-abuse', 1)
# ('x-mandrill-user', 1)
# ('x-msw-jemd-malware', 1)
# ('x-me-auth', 1)
# ('x-country-code', 1)
# ('x-cache-id', 1)
# ('message-context', 1)
# ('x-wum-signatureadded', 1)
# ('x-message-size', 1)
# ('x-savecopy', 1)
# ('x-national-code', 1)
# ('x-cache-entry', 1)
# ('x-wum-channeltype', 1)
# ('x-wum-nature', 1)
# ('x-wum-from', 1)
# ('x-wum-to', 1)
# ('x-wum-replyto', 1)
# ('x-ums', 1)
# ('x-csc', 1)
# ('x-cha', 1)
# ('x-ctch-score', 1)
# ('x-ctch-rules', 1)
# ('x-ctch-flags', 1)
# ('x-ctch-scorecust', 1)
# ('x-masterwebnetwork-domain', 1)
# ('x-masterwebnetwork-username', 1)
# ('x-masterwebnetwork-outgoing-class', 1)
# ('x-masterwebnetwork-outgoing-evidence', 1)
# ('x-smtp10-mailscanner-information', 1)
# ('x-smtp10-mailscanner-id', 1)
# ('x-smtp10-mailscanner', 1)
# ('x-cloudmilter-processed', 1)
# ('x-originating-smarthost01a-ip', 1)
# ('x-mdav-result', 1)
# ('x-ctch-error', 1)
# ('x-authenticated', 1)
# ('x-ratelimit', 1)
# ('x-outbound-ip', 1)
# ('x-env-from', 1)
# ('x-proto', 1)
# ('x-revdns', 1)
# ('x-helo', 1)
# ('x-tls', 1)
# ('x-authenticated_id', 1)
# ('x-policysmart', 1)
# ('x-antispam-training-forget', 1)
# ('x-antispam-training-nonspam', 1)
# ('x-antispam-training-phish', 1)
# ('x-antispam-training-spam', 1)
# ('x-incomingtopheadermarker', 1)
# ('x-tmn', 1)
# ('x-incomingheadercount', 1)
# ('x-ms-exchange-slblob-mailprops', 1)
# ('x-ms-exchange-crosstenant-rms-persistedconsumerorg', 1)
# ('x-kse-antispam-outbound-interceptor-info', 1)
# ('x-kse-antispam-version', 1)
# ('x-kse-antispam-status', 1)
# ('x-kse-antispam-method', 1)
# ('x-kse-antispam-rate', 1)
# ('x-kse-antispam-info', 1)
# ('x-kse-antiphishing-info', 1)
# ('x-kse-antiphishing-method', 1)
# ('x-kse-antiphishing-bases', 1)
# ('x-mailster', 1)
# ('x-mailster-campaign', 1)
# ('x-mailster-id', 1)
# ('list-unsubscribe-post', 1)
# ('x-message-id', 1)
# ('x-ort-llc-mailscanner-information', 1)
# ('x-ort-llc-mailscanner-id', 1)
# ('x-ort-llc-mailscanner', 1)
# ('x-ort-llc-mailscanner-from', 1)
# ('x-klms-rule-id', 1)
# ('x-klms-message-action', 1)
# ('x-klms-antispam-lua-profiles', 1)
# ('x-klms-antispam-version', 1)
# ('x-klms-antispam-envelope-from', 1)
# ('x-klms-antispam-rate', 1)
# ('x-klms-antispam-status', 1)
# ('x-klms-antispam-method', 1)
# ('x-klms-antispam-info', 1)
# ('x-klms-antispam-interceptor-info', 1)
# ('x-klms-antiphishing', 1)
# ('x-klms-antivirus', 1)
# ('x-klms-antivirus-status', 1)
# ('x-additional-header', 1)
# ('x-virus-found', 1)
# ('x-lookup-warning', 1)
# ('x-ovh-tracer-id', 1)
# ('x-vr-spamstate', 1)
# ('x-vr-spamscore', 1)
# ('x-vr-spamcause', 1)
# ('x-tm-as-smtp', 1)
# ('x-tm-as-ers', 1)
# ('x-terrace-dummysubject', 1)
# ('x-terrace-spammark', 1)
# ('x-terrace-classid', 1)
# ('x-c2processedorg', 1)
# ('x-spamh-filter', 1)
# ('x-spamh-originatingip', 1)
# ('x-authentication-warning', 1)
# ('x-mj-mid', 1)
# ('x-mj-smtpguid', 1)
# ('x-hmdnsgroup-mailscanner-information', 1)
# ('x-hmdnsgroup-mailscanner-id', 1)
# ('x-hmdnsgroup-mailscanner', 1)
# ('x-hmdnsgroup-mailscanner-spamcheck', 1)
# ('x-hmdnsgroup-mailscanner-from', 1)
# ('x-forwarded-for', 1)
# ('x-auth', 1)
# ('x-cmae-envelope', 1)
# ('x-tamu-auth-id', 1)
# ('x-tamu-senderip', 1)
# ('x-tamu-auth', 1)
# ('x-clx-shades', 1)
# ('x-clx-response', 1)
# ('x-ironport-remoteip', 1)
# ('x-ironport-mid', 1)
# ('x-ironport-reputation', 1)
# ('x-ironport-listener', 1)
# ('x-ironport-sendergroup', 1)
# ('x-ironport-mailflowpolicy', 1)
# ('x-cloudmark-score', 1)
# ('x-unknown-null', 1)
# ('x-synaq-pinpoint-information', 1)
# ('x-synaq-pinpoint-id', 1)
# ('x-synaq-pinpoint', 1)
# ('x-synaq-pinpoint-spamcheck', 1)
# ('x-synaq-pinpoint-spamscore', 1)
# ('x-pinpoint-from', 1)
# ('x-acl-warn', 1)
# ('x-bypsheader', 1)
# ('x-smscore', 1)
# ('x-lcid', 1)
# ('x-sm_envelopefrom', 1)
# ('x-sm_received_on', 1)
# ('x-cpanel-mailscanner-information', 1)
# ('x-cpanel-mailscanner-id', 1)
# ('x-cpanel-mailscanner', 1)
# ('x-cpanel-mailscanner-spamcheck', 1)
# ('x-cpanel-mailscanner-spamscore', 1)
# ('x-cpanel-mailscanner-from', 1)
# ('x-sender-id', 1)
# ('x-type', 1)
# ('x-toi-expurgateid', 1)
# ('x-amp-result', 1)
# ('x-amp-file-uploaded', 1)
# ('x-ctch-av-threatscount', 1)
# ('x-en-sp-dir', 1)
# ('x-en-sp-sq', 1)
# ('disposition-notification-options', 1)
# ('x-msg-eid', 1)
# ('cc', 1)
# ('x-dropbox-message-id', 1)
# ('x-mn-spam-dtl', 1)
# ('x-biz-relay', 1)
# ('x-default-received-spf', 1)
# TOTAL EMAIL COUNT: 1012
